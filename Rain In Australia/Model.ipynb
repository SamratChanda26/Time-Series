# %% [markdown]
# # 0. Install and Import Dependencies

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from neuralprophet import NeuralProphet
from matplotlib import pyplot as plt
import pickle

# %% [markdown]
# # 1. Read in Data and Process Dates

# %%
df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
syd = df[df['Location']=='Sydney']
syd['Date'] = pd.to_datetime(syd['Date'])
syd.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 30176 2008-02-01   Sydney     19.5     22.4      15.6          6.2       0.0
# 30177 2008-02-02   Sydney     19.5     25.6       6.0          3.4       2.7
# 30178 2008-02-03   Sydney     21.6     24.5       6.6          2.4       0.1
# 30179 2008-02-04   Sydney     20.2     22.8      18.8          2.2       0.0
# 30180 2008-02-05   Sydney     19.7     25.7      77.4          NaN       0.0
#
#       WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 30176         NaN            NaN          S  ...        92.0         84.0
# 30177         NaN            NaN          W  ...        83.0         73.0
# 30178         NaN            NaN        ESE  ...        88.0         86.0
# 30179         NaN            NaN        NNE  ...        83.0         90.0
# 30180         NaN            NaN        NNE  ...        88.0         74.0
#
# ...

# %%
syd.dtypes
# Out:
# Date             datetime64[ns]
# Location                 object
# MinTemp                 float64
# MaxTemp                 float64
# Rainfall                float64
# Evaporation             float64
# Sunshine                float64
# WindGustDir              object
# WindGustSpeed           float64
# WindDir9am               object
# WindDir3pm               object
# WindSpeed9am            float64
# WindSpeed3pm            float64
# Humidity9am             float64
# Humidity3pm             float64
# Pressure9am             float64
# Pressure3pm             float64
# Cloud9am                float64
# Cloud3pm                float64
# Temp9am                 float64
# Temp3pm                 float64
# RainToday                object
# RainTomorrow             object
# dtype: object

# %%
plt.plot(syd['Date'], syd['Temp3pm'])
plt.show()

# %% [markdown]
# ## Example of cut off missing values

# %%
"""
syn['Year'] = syd['Date'].apply(lambda x: x.year)
syd = syd[syd['Year']<=2015]
plt.plot(syd['Date'], syd['Temp3pm'])
plt.show()
"""
# Out:
# "\nsyn['Year'] = syd['Date'].apply(lambda x: x.year)\nsyd = syd[syd['Year']<=2015]\nplt.plot(syd['Date'], syd['Temp3pm'])\nplt.show()\n"

# %%
# syd.head() / tail()

# %%
data = syd[['Date', 'Temp3pm']]
data.dropna(inplace=True)
data.columns = ['ds', 'y'] # NeuralProphet expects inputs to be 'ds' and 'y'
data.head()
# Out:
#               ds     y
# 30176 2008-02-01  20.9
# 30177 2008-02-02  24.8
# 30178 2008-02-03  23.0
# 30179 2008-02-04  20.9
# 30180 2008-02-05  25.5

# %%
data
# Out:
#               ds     y
# 30176 2008-02-01  20.9
# 30177 2008-02-02  24.8
# 30178 2008-02-03  23.0
# 30179 2008-02-04  20.9
# 30180 2008-02-05  25.5
# ...          ...   ...
# 33515 2017-06-21  17.9
# 33516 2017-06-22  18.7
# 33517 2017-06-23  17.3
# 33518 2017-06-24  19.0
# 33519 2017-06-25  18.8
#
# [3340 rows x 2 columns]

# %% [markdown]
# # 2. Train Model

# %%
m = NeuralProphet()
m.fit(data, freq = 'D', epochs = 1000) # Freq is D as our data frame is in a daily frequency
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.76% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (105) is too small than the required number for the learning rate finder (238). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/238 [00:03<?, ?it/s]
# Training: 0it [00:00, ?it/s]
#            MAE       RMSE      Loss  RegLoss  epoch
# ...

# %% [markdown]
# # 3. Forecast Prediction

# %%
future = m.make_future_dataframe(data, periods=900)
forecast = m.predict(future)
forecast.head()
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.76% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.889% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.889% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 105it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#           ds     y      yhat1      trend  season_yearly  season_weekly
# 0 2017-06-26  None  17.250772  22.261608      -4.990607      -0.020228
# 1 2017-06-27  None  17.230309  22.262211      -4.999393      -0.032512
# ...

# %%
future
# Out:
#             ds     y
# 0   2017-06-26  None
# 1   2017-06-27  None
# 2   2017-06-28  None
# 3   2017-06-29  None
# 4   2017-06-30  None
# ..         ...   ...
# 895 2019-12-08  None
# 896 2019-12-09  None
# 897 2019-12-10  None
# 898 2019-12-11  None
# 899 2019-12-12  None
#
# [900 rows x 2 columns]

# %%
forecast.tail()
# Out:
#             ds     y      yhat1      trend  season_yearly  season_weekly
# 895 2019-12-08  None  24.942644  22.803375       2.209151      -0.069884
# 896 2019-12-09  None  25.011333  22.803982       2.227580      -0.020228
# 897 2019-12-10  None  25.019426  22.804588       2.247350      -0.032512
# 898 2019-12-11  None  24.986504  22.805193       2.268708      -0.087396
# 899 2019-12-12  None  25.252220  22.805798       2.291886       0.154537

# %%
plot1 = m.plot(forecast)
plot1.show()
# Out:
# <div>                            <div id="40ae3ba4-bfd3-41c7-808a-7246b1499a78" class="plotly-graph-div" style="height:420px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40ae3ba4-bfd3-41c7-808a-7246b1499a78")) {                    Plotly.newPlot(                        "40ae3ba4-bfd3-41c7-808a-7246b1499a78",                        [{"fill":"none","line":{"color":"rgba(45, 146, 255, 1.0)","width":2},"mode":"lines","name":"yhat1","uid":"1780e507-7b35-49a6-8469-2cfe08222119","x":["2017-06-26T00:00:00","2017-06-27T00:00:00","2017-06-28T00:00:00","2017-06-29T00:00:00","2017-06-30T00:00:00","2017-07-01T00:00:00","2017-07-02T00:00:00","2017-07-03T00:00:00","2017-07-04T00:00:00","2017-07-05T00:00:00","2017-07-06T00:00:00","2017-07-07T00:00:00","2017-07-08T00:00:00","2017-07-09T00:00:00","2017-07-1
# ...

# %%
plot2 = m.plot_components(forecast)
plot2.show()
# Out:
# <div>                            <div id="ad2695c5-568e-474e-a1a9-3785c71742b7" class="plotly-graph-div" style="height:630px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2695c5-568e-474e-a1a9-3785c71742b7")) {                    Plotly.newPlot(                        "ad2695c5-568e-474e-a1a9-3785c71742b7",                        [{"line":{"color":"#2d92ff","width":2},"mode":"lines","name":"Trend","showlegend":false,"uid":"95cad7d6-269a-4bd6-b9c9-94a8161d33a0","x":["2017-06-26T00:00:00","2017-06-27T00:00:00","2017-06-28T00:00:00","2017-06-29T00:00:00","2017-06-30T00:00:00","2017-07-01T00:00:00","2017-07-02T00:00:00","2017-07-03T00:00:00","2017-07-04T00:00:00","2017-07-05T00:00:00","2017-07-06T00:00:00","2017-07-07T00:00:00","2017-07-08T00:00:00","2017-07-09T00:00:00","2017-07-10T00:00:00"
# ...

# %% [markdown]
# # 4. Save Model

# %%
with open('forecast_model.pkl', "wb") as f:
    pickle.dump(m, f)

# %%
del m

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/samrat/Machine Learning/Kaggle/Projects/Time Series - Weather Analysis And Forecasting/Rain In Australia/Model.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/samrat/Machine%20Learning/Kaggle/Projects/Time%20Series%20-%20Weather%20Analysis%20And%20Forecasting/Rain%20In%20Australia/Model.ipynb#X35sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> m
#
# NameError: name 'm' is not defined

# %%
with open('forecast_model.pkl', "rb") as f:
    m = pickle.load(f)

# %%
m
